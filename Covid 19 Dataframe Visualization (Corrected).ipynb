# %%
# for analyzing, cleaning, exploring, and manipulating data.
import pandas as pd

# for working with arrays
import numpy as np

#  for creating static, animated, and interactive visualizations in Python
import matplotlib.pyplot as plt

# for data visualization
import seaborn as sns

# for containing functions that can create entire figures at once
import plotly.express as px
from plotly.subplots import make_subplots

# for manipulating dates and times
from datetime import datetime

# %%
# importing dataset

vaccine_df = pd.read_csv("F:/Python Project Homework/My Project Homework/covid_vaccine_statewise.csv")

# %%
# importing dataset

covid_df = pd.read_csv("F:/Python Project Homework/My Project Homework/covid_19_india.csv")

# %%
covid_df
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 18105  18106  2021-08-11  8:00 AM            Telangana
# 18106  18107  2021-08-11  8:00 AM              Tripura
# 18107  18108  2021-08-11  8:00 AM          Uttarakhand
# 18108  18109  2021-08-11  8:00 AM        Uttar Pradesh
# 18109  18110  2021-08-11  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %%
vaccine_df
# Out:
#       Updated On        State  Total Doses Administered  Sessions   Sites   \
# 0     16/01/2021        India                   48276.0    3455.0   2957.0
# 1     17/01/2021        India                   58604.0    8532.0   4954.0
# 2     18/01/2021        India                   99449.0   13611.0   6583.0
# 3     19/01/2021        India                  195525.0   17855.0   7951.0
# 4     20/01/2021        India                  251280.0   25472.0  10504.0
# ...          ...          ...                       ...       ...      ...
# 7840  11/08/2021  West Bengal                       NaN       NaN      NaN
# 7841  12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842  13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843  14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844  15/08/2021  West Bengal                       NaN       NaN      NaN
#
#       First Dose Administered  Second Dose Administered  \
# ...

# %%
# information about the dataset

covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18110 entries, 0 to 18109
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       18110 non-null  int64
#  1   Date                      18110 non-null  object
#  2   Time                      18110 non-null  object
#  3   State/UnionTerritory      18110 non-null  object
#  4   ConfirmedIndianNational   18110 non-null  object
#  5   ConfirmedForeignNational  18110 non-null  object
#  6   Cured                     18110 non-null  int64
#  7   Deaths                    18110 non-null  int64
#  8   Confirmed                 18110 non-null  int64
# dtypes: int64(4), object(5)
# memory usage: 1.2+ MB

# %%
vaccine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7845 entries, 0 to 7844
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Updated On                           7845 non-null   object
#  1   State                                7845 non-null   object
#  2   Total Doses Administered             7621 non-null   float64
#  3   Sessions                             7621 non-null   float64
#  4    Sites                               7621 non-null   float64
#  5   First Dose Administered              7621 non-null   float64
#  6   Second Dose Administered             7621 non-null   float64
#  7   Male (Doses Administered)            7461 non-null   float64
#  8   Female (Doses Administered)          7461 non-null   float64
#  9   Transgender (Doses Administered)     7461 non-null   float64
#  10   Covaxin (Doses Administered)        7621 non-null   float64
# ...

# %%
# to get some idea about the statistical analyis (count, mean, std deviation, max, min, etc.)

covid_df.describe()
# Out:
#                 Sno         Cured         Deaths     Confirmed
# count  18110.000000  1.811000e+04   18110.000000  1.811000e+04
# mean    9055.500000  2.786375e+05    4052.402264  3.010314e+05
# std     5228.051023  6.148909e+05   10919.076411  6.561489e+05
# min        1.000000  0.000000e+00       0.000000  0.000000e+00
# 25%     4528.250000  3.360250e+03      32.000000  4.376750e+03
# 50%     9055.500000  3.336400e+04     588.000000  3.977350e+04
# 75%    13582.750000  2.788698e+05    3643.750000  3.001498e+05
# max    18110.000000  6.159676e+06  134201.000000  6.363442e+06

# %%
vaccine_df.describe()
# Out:
#        Total Doses Administered      Sessions        Sites   \
# count              7.621000e+03  7.621000e+03   7621.000000
# mean               9.188171e+06  4.792358e+05   2282.872064
# std                3.746180e+07  1.911511e+06   7275.973730
# min                7.000000e+00  0.000000e+00      0.000000
# 25%                1.356570e+05  6.004000e+03     69.000000
# 50%                8.182020e+05  4.547000e+04    597.000000
# 75%                6.625243e+06  3.428690e+05   1708.000000
# max                5.132284e+08  3.501031e+07  73933.000000
#
#        First Dose Administered  Second Dose Administered  \
# count             7.621000e+03              7.621000e+03
# mean              7.414415e+06              1.773755e+06
# std               2.995209e+07              7.570382e+06
# min               7.000000e+00              0.000000e+00
# 25%               1.166320e+05              1.283100e+04
# 50%               6.614590e+05              1.388180e+05
# ...

# %%
# dropping unnessesary columns form the first dataset. if you want to override the dataframe then inplace = True
# axis = 0 represent rows and axis = 1 represent column
covid_df.drop(["Sno", "Time", "ConfirmedIndianNational", "ConfirmedForeignNational"], inplace = True, axis = 1)

# %%
covid_df
# Out:
#              Date State/UnionTerritory    Cured  Deaths  Confirmed
# 0      2020-01-30               Kerala        0       0          1
# 1      2020-01-31               Kerala        0       0          1
# 2      2020-02-01               Kerala        0       0          2
# 3      2020-02-02               Kerala        0       0          3
# 4      2020-02-03               Kerala        0       0          3
# ...           ...                  ...      ...     ...        ...
# 18105  2021-08-11            Telangana   638410    3831     650353
# 18106  2021-08-11              Tripura    77811     773      80660
# 18107  2021-08-11          Uttarakhand   334650    7368     342462
# 18108  2021-08-11        Uttar Pradesh  1685492   22775    1708812
# 18109  2021-08-11          West Bengal  1506532   18252    1534999
#
# [18110 rows x 5 columns]

# %%
# change the fomrmat of the date column

covid_df["Date"] = pd.to_datetime(covid_df["Date"], format = '%Y-%m-%d')

# %%
# to find total number of active cases, we have to subtract
#from total number of confirmed cases to sum of (cured cases + death reports)

# %%
# Active Cases

covid_df['active_cases'] = covid_df['Confirmed'] - (covid_df['Cured'] + covid_df['Deaths'])

# %%
covid_df.tail()
# Out:
#             Date State/UnionTerritory    Cured  Deaths  Confirmed  \
# 18105 2021-08-11            Telangana   638410    3831     650353
# 18106 2021-08-11              Tripura    77811     773      80660
# 18107 2021-08-11          Uttarakhand   334650    7368     342462
# 18108 2021-08-11        Uttar Pradesh  1685492   22775    1708812
# 18109 2021-08-11          West Bengal  1506532   18252    1534999
#
#        active_cases
# 18105          8112
# 18106          2076
# 18107           444
# 18108           545
# 18109         10215

# %%
# making a pivot table using pandas library
# index() method helps you find the index position of an element or an item in a string of characters or a list of items.
# aggfunc is column to aggregate and value is function or list of functions.

statewise = pd.pivot_table(covid_df, values = ["Confirmed", "Deaths", "Cured"], index = "State/UnionTerritory", aggfunc = max)

# %%
# making a recovery rate in percentage
# so we have to multiply the (cured/ confirmed) and multipled with 100


statewise["Recovery Rate"] = statewise["Cured"]*100/statewise["Confirmed"]

# %%
# making a mortality rate in percentage
# so we have to multiply the (deaths/confirmed) * 100


statewise["Mortality Rate"] = statewise["Deaths"]*100/statewise["Confirmed"]

# %%
# sort the values in the basis of confirmed columns in descending order

statewise = statewise.sort_values(by = "Confirmed", ascending = False)

# %%
# plotting a pivot table using a nice visual
# for this we have to use background_gradient function
# cmap stands for colour map which present in the matplotlib library

statewise.style.background_gradient(cmap = "cubehelix")
# Out:
# <style type="text/css">
# #T_b0efe_row0_col0, #T_b0efe_row0_col1, #T_b0efe_row0_col2, #T_b0efe_row20_col4, #T_b0efe_row39_col3 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_b0efe_row0_col3, #T_b0efe_row31_col3 {
#   background-color: #f0fbf5;
#   color: #000000;
# }
# #T_b0efe_row0_col4 {
#   background-color: #c3bff2;
#   color: #000000;
# }
# #T_b0efe_row1_col0, #T_b0efe_row3_col3, #T_b0efe_row4_col3, #T_b0efe_row5_col3, #T_b0efe_row24_col3, #T_b0efe_row27_col3, #T_b0efe_row28_col3, #T_b0efe_row29_col3 {
#   background-color: #f6fcf8;
#   color: #000000;
# }
# #T_b0efe_row1_col1, #T_b0efe_row1_col2, #T_b0efe_row20_col3, #T_b0efe_row26_col3 {
#   background-color: #f4fcf7;
#   color: #000000;
# }
# #T_b0efe_row1_col3 {
#   background-color: #effaf4;
#   color: #000000;
# }
# #T_b0efe_row1_col4 {
#   background-color: #c4bdf1;
#   color: #000000;
# }
# #T_b0efe_row2_col0 {
#   background-color: #c57a76;
#   color: #f1f1f1;
# }
# #T_b0efe_row2_col1 {
# ...

# %%
# top 10 active cases states
# for this query we have to use another pandas function which is called as groupby
# we group by the columns by states followed by max() which can help us to find maximum values in states that have active cases and 
#we sort the values by active cases in descending order and then reset the index 
# for that we have to use the reset_index() function


Top_10_Active_Cases = covid_df.groupby(by = "State/UnionTerritory").max()[["active_cases", "Date"]].sort_values(by = ["active_cases"], ascending = False).reset_index()

# %%
Top_10_Active_Cases
# Out:
#                         State/UnionTerritory  active_cases       Date
# 0                                Maharashtra        701614 2021-08-11
# 1                                  Karnataka        605515 2021-08-11
# 2                                     Kerala        445692 2021-08-11
# 3                                 Tamil Nadu        313048 2021-08-11
# 4                              Uttar Pradesh        310783 2021-08-11
# 5                                  Rajasthan        212753 2021-08-11
# 6                             Andhra Pradesh        211554 2021-08-11
# 7                                    Gujarat        148297 2021-08-11
# 8                                West Bengal        132181 2021-08-11
# 9                               Chhattisgarh        131245 2021-08-11
# 10                                   Haryana        116867 2021-08-11
# 11                                     Bihar        115152 2021-08-11
# ...

# %%
Top_10_Active_Cases = covid_df.groupby(by = "State/UnionTerritory").max()[["active_cases", "Date"]].sort_values(by = ["active_cases"], ascending = False).reset_index() 
fig = plt.figure(figsize = (16,9))
plt.title("Top 10 States", size = 25)
ax = sns.barplot(data = Top_10_Active_Cases.iloc[:10], y = "active_cases", x = "State/UnionTerritory", linewidth = 2, edgecolor = "red")
plt.xlabel("States")
plt.ylabel("Total Active Cases")
plt.show()

# %%
# now we will se the top 10 states on the basis of deaths columns

top_10_deaths = covid_df.groupby(by = "State/UnionTerritory").max()[["Deaths", "Date"]].sort_values(by = ["Deaths"], ascending = False).reset_index()

# %%
fig = plt.figure(figsize = (18,5))
plt.title("Top 10 States for Deaths", size = 25)
ax = sns.barplot(data = top_10_deaths.iloc[:12], y = "Deaths", x = "State/UnionTerritory", linewidth = 2, edgecolor = "black")
plt.xlabel("States")
plt.ylabel("Total Death Cases")
plt.show()

# %%
# Line Plot to see most number of confirmed cases

# Growth Trend

fig = plt.figure(figsize = (12,6))

# %%
#ax = sns.lineplot(data = covid_df[covid_df['State/UnionTerritory'].isin(['Maharashtra', 'Karnataka', 'Kerala', 'Tamil Nadu', 'Uttar Pradesh'])], x = 'Date', y= 'active_cases', hue = 'State/UnionTerritory'])
fig = plt.figure(figsize = (12,6))
ax = sns.lineplot(data=covid_df[covid_df['State/UnionTerritory'].isin(['Maharashtra', 'Karnataka', 'Kerala', 'Tamil Nadu', 'Uttar Pradesh'])], x='Date', y='active_cases', hue='State/UnionTerritory')
ax.set_title("Top 5 affected state in India", size = 16)
# Out:
# Text(0.5, 1.0, 'Top 5 affected state in India')

# %% [markdown]
# # Second Dataset Manipulation

# %%
vaccine_df.head()
# Out:
#    Updated On  State  Total Doses Administered  Sessions   Sites   \
# 0  16/01/2021  India                   48276.0    3455.0   2957.0
# 1  17/01/2021  India                   58604.0    8532.0   4954.0
# 2  18/01/2021  India                   99449.0   13611.0   6583.0
# 3  19/01/2021  India                  195525.0   17855.0   7951.0
# 4  20/01/2021  India                  251280.0   25472.0  10504.0
#
#    First Dose Administered  Second Dose Administered  \
# 0                  48276.0                       0.0
# 1                  58604.0                       0.0
# 2                  99449.0                       0.0
# 3                 195525.0                       0.0
# 4                 251280.0                       0.0
#
#    Male (Doses Administered)  Female (Doses Administered)  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# ...

# %%
# Rename Update on column to vaccine date column
#using pandas library and rename function

vaccine_df.rename(columns = {'Updated On': 'Vaccine_date'}, inplace = True)

# %%
vaccine_df.head()
# Out:
#   Vaccine_date  State  Total Doses Administered  Sessions   Sites   \
# 0   16/01/2021  India                   48276.0    3455.0   2957.0
# 1   17/01/2021  India                   58604.0    8532.0   4954.0
# 2   18/01/2021  India                   99449.0   13611.0   6583.0
# 3   19/01/2021  India                  195525.0   17855.0   7951.0
# 4   20/01/2021  India                  251280.0   25472.0  10504.0
#
#    First Dose Administered  Second Dose Administered  \
# 0                  48276.0                       0.0
# 1                  58604.0                       0.0
# 2                  99449.0                       0.0
# 3                 195525.0                       0.0
# 4                 251280.0                       0.0
#
#    Male (Doses Administered)  Female (Doses Administered)  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# ...

# %%
# find the sum of the missing values from the dataframe

vaccine_df.isnull().sum()
# Out:
# Vaccine_date                              0
# State                                     0
# Total Doses Administered                224
# Sessions                                224
#  Sites                                  224
# First Dose Administered                 224
# Second Dose Administered                224
# Male (Doses Administered)               384
# Female (Doses Administered)             384
# Transgender (Doses Administered)        384
#  Covaxin (Doses Administered)           224
# CoviShield (Doses Administered)         224
# Sputnik V (Doses Administered)         4850
# AEFI                                   2407
# 18-44 Years (Doses Administered)       6143
# 45-60 Years (Doses Administered)       6143
# 60+ Years (Doses Administered)         6143
# 18-44 Years(Individuals Vaccinated)    4112
# 45-60 Years(Individuals Vaccinated)    4111
# 60+ Years(Individuals Vaccinated)      4111
# Male(Individuals Vaccinated)           7685
# ...

# %%
# sum of the columns have to drop and stored on the new dataframe

vaccination = vaccine_df.drop(columns = ['Sputnik V (Doses Administered)', 'AEFI', '18-44 Years(Individuals Vaccinated)', '45-60 Years(Individuals Vaccinated)', '60+ Years(Individuals Vaccinated)'], axis = 1)

# %%
vaccination.head()
# Out:
#   Vaccine_date  State  Total Doses Administered  Sessions   Sites   \
# 0   16/01/2021  India                   48276.0    3455.0   2957.0
# 1   17/01/2021  India                   58604.0    8532.0   4954.0
# 2   18/01/2021  India                   99449.0   13611.0   6583.0
# 3   19/01/2021  India                  195525.0   17855.0   7951.0
# 4   20/01/2021  India                  251280.0   25472.0  10504.0
#
#    First Dose Administered  Second Dose Administered  \
# 0                  48276.0                       0.0
# 1                  58604.0                       0.0
# 2                  99449.0                       0.0
# 3                 195525.0                       0.0
# 4                 251280.0                       0.0
#
#    Male (Doses Administered)  Female (Doses Administered)  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# ...

# %%
# Male vs Female Vaccination
# this querry can be done via plotly library

male = vaccine_df["Male(Individuals Vaccinated)"].sum()
female = vaccine_df["Female(Individuals Vaccinated)"].sum()
px.pie(names = ["Male", "Female"], values = ["Male", "Female"], title = "Male and Female Vaccination")
# Out:
# <div>                            <div id="e0b9355d-53e1-41b2-b772-37f8cce43c49" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0b9355d-53e1-41b2-b772-37f8cce43c49")) {                    Plotly.newPlot(                        "e0b9355d-53e1-41b2-b772-37f8cce43c49",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["Male","Female"],"legendgroup":"","name":"","showlegend":true,"values":["Male","Female"],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.333333333333333
# ...

# %%
# remove states where states is India

vaccine = vaccine_df[vaccine_df.State != 'India']

# %%
vaccine.head()
# Out:
#     Vaccine_date                        State  Total Doses Administered  \
# 212   16/01/2021  Andaman and Nicobar Islands                      23.0
# 213   17/01/2021  Andaman and Nicobar Islands                      23.0
# 214   18/01/2021  Andaman and Nicobar Islands                      42.0
# 215   19/01/2021  Andaman and Nicobar Islands                      89.0
# 216   20/01/2021  Andaman and Nicobar Islands                     124.0
#
#      Sessions   Sites   First Dose Administered  Second Dose Administered  \
# 212       2.0      2.0                     23.0                       0.0
# 213       2.0      2.0                     23.0                       0.0
# 214       9.0      2.0                     42.0                       0.0
# 215      12.0      2.0                     89.0                       0.0
# 216      16.0      3.0                    124.0                       0.0
#
#      Male (Doses Administered)  Female (Doses Administered)  \
# ...

# %%
vaccine.rename(columns = {'Total Individuals Vaccinated': 'Total'}, inplace = True)
vaccine.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5408\2441818440.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     Vaccine_date                        State  Total Doses Administered  \
# 212   16/01/2021  Andaman and Nicobar Islands                      23.0
# 213   17/01/2021  Andaman and Nicobar Islands                      23.0
# 214   18/01/2021  Andaman and Nicobar Islands                      42.0
# 215   19/01/2021  Andaman and Nicobar Islands                      89.0
# 216   20/01/2021  Andaman and Nicobar Islands                     124.0
#
#      Sessions   Sites   First Dose Administered  Second Dose Administered  \
# 212       2.0      2.0                     23.0                       0.0
# 213       2.0      2.0                     23.0                       0.0
# ...

# %%
# Most Vaccinated State
# for this querry we need to use groupby function

max_vac = vaccine.groupby('State')['Total'].sum().to_frame('Total')
max_vac = max_vac.sort_values('Total', ascending = False)[:5]
max_vac
# Out:
#                       Total
# State
# Maharashtra    1.403075e+09
# Uttar Pradesh  1.200575e+09
# Rajasthan      1.141163e+09
# Gujarat        1.078261e+09
# West Bengal    9.250227e+08

# %%
fig = plt.figure(figsize = (10,5))
plt.title('Top 5 Vaccinated State in India', size = 20)
x = sns.barplot(data = max_vac.iloc[:10], y = max_vac.Total, x = max_vac.index, linewidth = 2, edgecolor = 'black')
plt.xlabel = ('States')
plt.ylabel = ('Vaccination')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# find the least number of vaccinated states
# convert the data into a bar plot 

min_vac = vaccine.groupby('State')['Total'].sum().to_frame('Total')
min_vac = max_vac.sort_values('Total', ascending = True)[:-5]
min_vac
# Out:
# Empty DataFrame
# Columns: [Total]
# Index: []
